# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv

# %%
df = pd.read_csv('/kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.drop(columns = ['RowNumber','CustomerId','Surname'],inplace=True)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
df['Exited'].value_counts()
# Out:
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
# This function is used as LabelEncoder
df = pd.get_dummies(df,columns=['Geography','Gender'],drop_first=True)

# %%
df.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
# 2               0        113931.57       1                  0
# 3               0         93826.63       0                  0
# 4               1         79084.10       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0
# 2                0            0
# 3                0            0
# 4                1            0

# %%
# It is recommended to scale values before training the data in neural network.
# Scaling the values means convert the values in a feasible range.

# %%
X = df.drop(columns=['Exited'])
y = df['Exited'].values

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_trf = scaler.fit_transform(X_train)
X_test_trf = scaler.transform(X_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(11,activation='relu',input_dim=11))
model.add(Dense(11,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 11)                132
# _________________________________________________________________
# dense_4 (Dense)              (None, 11)                132
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 12
# =================================================================
# Total params: 276
# Trainable params: 276
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(X_train_trf,y_train,epochs=100,validation_split=0.2)
# Out:
# Epoch 1/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.5402 - accuracy: 0.7620 - val_loss: 0.4785 - val_accuracy: 0.7969
# Epoch 2/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4552 - accuracy: 0.8002 - val_loss: 0.4458 - val_accuracy: 0.8062
# Epoch 3/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4336 - accuracy: 0.8072 - val_loss: 0.4335 - val_accuracy: 0.8112
# Epoch 4/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4235 - accuracy: 0.8152 - val_loss: 0.4256 - val_accuracy: 0.8119
# Epoch 5/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4155 - accuracy: 0.8228 - val_loss: 0.4173 - val_accuracy: 0.8163
# Epoch 6/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.4059 - accuracy: 0.8295 - val_loss: 0.4097 - val_accuracy: 0.8225
# Epoch 7/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.8350 - val_loss: 0.3985 - val_accuracy: 0.8250
# Epoch 8/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3806 - accuracy: 0.8414 - val_loss: 0.3852 - val_accuracy: 0.8350
# Epoch 9/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3670 - accuracy: 0.8502 - val_loss: 0.3759 - val_accuracy: 0.8388
# Epoch 10/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3569 - accuracy: 0.8536 - val_loss: 0.3687 - val_accuracy: 0.8456
# Epoch 11/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3491 - accuracy: 0.8559 - val_loss: 0.3632 - val_accuracy: 0.8519
# Epoch 12/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3443 - accuracy: 0.8591 - val_loss: 0.3600 - val_accuracy: 0.8531
# Epoch 13/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3414 - accuracy: 0.8584 - val_loss: 0.3583 - val_accuracy: 0.8519
# Epoch 14/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3389 - accuracy: 0.8581 - val_loss: 0.3576 - val_accuracy: 0.8569
# Epoch 15/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3371 - accuracy: 0.8620 - val_loss: 0.3561 - val_accuracy: 0.8587
# Epoch 16/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3351 - accuracy: 0.8611 - val_loss: 0.3559 - val_accuracy: 0.8556
# Epoch 17/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3349 - accuracy: 0.8612 - val_loss: 0.3553 - val_accuracy: 0.8569
# Epoch 18/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3330 - accuracy: 0.8630 - val_loss: 0.3542 - val_accuracy: 0.8537
# Epoch 19/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8631 - val_loss: 0.3547 - val_accuracy: 0.8575
# Epoch 20/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3315 - accuracy: 0.8633 - val_loss: 0.3536 - val_accuracy: 0.8581
# Epoch 21/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3310 - accuracy: 0.8634 - val_loss: 0.3539 - val_accuracy: 0.8594
# Epoch 22/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3298 - accuracy: 0.8617 - val_loss: 0.3536 - val_accuracy: 0.8575
# Epoch 23/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3301 - accuracy: 0.8627 - val_loss: 0.3541 - val_accuracy: 0.8587
# Epoch 24/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3293 - accuracy: 0.8653 - val_loss: 0.3549 - val_accuracy: 0.8575
# Epoch 25/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3283 - accuracy: 0.8648 - val_loss: 0.3532 - val_accuracy: 0.8569
# Epoch 26/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3284 - accuracy: 0.8637 - val_loss: 0.3538 - val_accuracy: 0.8575
# Epoch 27/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3281 - accuracy: 0.8653 - val_loss: 0.3543 - val_accuracy: 0.8544
# Epoch 28/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3273 - accuracy: 0.8642 - val_loss: 0.3547 - val_accuracy: 0.8537
# Epoch 29/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3267 - accuracy: 0.8644 - val_loss: 0.3543 - val_accuracy: 0.8562
# Epoch 30/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8653 - val_loss: 0.3552 - val_accuracy: 0.8562
# Epoch 31/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3261 - accuracy: 0.8653 - val_loss: 0.3569 - val_accuracy: 0.8562
# Epoch 32/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3259 - accuracy: 0.8648 - val_loss: 0.3547 - val_accuracy: 0.8587
# Epoch 33/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3259 - accuracy: 0.8655 - val_loss: 0.3556 - val_accuracy: 0.8544
# Epoch 34/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3253 - accuracy: 0.8658 - val_loss: 0.3562 - val_accuracy: 0.8569
# Epoch 35/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3254 - accuracy: 0.8642 - val_loss: 0.3561 - val_accuracy: 0.8562
# Epoch 36/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3250 - accuracy: 0.8667 - val_loss: 0.3550 - val_accuracy: 0.8562
# Epoch 37/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3240 - accuracy: 0.8670 - val_loss: 0.3561 - val_accuracy: 0.8544
# Epoch 38/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3241 - accuracy: 0.8661 - val_loss: 0.3561 - val_accuracy: 0.8562
# Epoch 39/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3237 - accuracy: 0.8670 - val_loss: 0.3570 - val_accuracy: 0.8556
# Epoch 40/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3238 - accuracy: 0.8673 - val_loss: 0.3565 - val_accuracy: 0.8544
# Epoch 41/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3233 - accuracy: 0.8637 - val_loss: 0.3566 - val_accuracy: 0.8575
# Epoch 42/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3232 - accuracy: 0.8669 - val_loss: 0.3569 - val_accuracy: 0.8575
# Epoch 43/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3225 - accuracy: 0.8669 - val_loss: 0.3584 - val_accuracy: 0.8562
# Epoch 44/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3225 - accuracy: 0.8675 - val_loss: 0.3568 - val_accuracy: 0.8581
# Epoch 45/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3221 - accuracy: 0.8673 - val_loss: 0.3573 - val_accuracy: 0.8569
# Epoch 46/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3224 - accuracy: 0.8656 - val_loss: 0.3580 - val_accuracy: 0.8562
# Epoch 47/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3216 - accuracy: 0.8664 - val_loss: 0.3575 - val_accuracy: 0.8544
# Epoch 48/100
# 200/200 [==============================] - 1s 3ms/step - loss: 0.3212 - accuracy: 0.8659 - val_loss: 0.3573 - val_accuracy: 0.8581
# Epoch 49/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3211 - accuracy: 0.8664 - val_loss: 0.3586 - val_accuracy: 0.8575
# Epoch 50/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3215 - accuracy: 0.8675 - val_loss: 0.3588 - val_accuracy: 0.8562
# Epoch 51/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3210 - accuracy: 0.8662 - val_loss: 0.3581 - val_accuracy: 0.8575
# Epoch 52/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3207 - accuracy: 0.8666 - val_loss: 0.3592 - val_accuracy: 0.8581
# Epoch 53/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8662 - val_loss: 0.3583 - val_accuracy: 0.8581
# Epoch 54/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3205 - accuracy: 0.8670 - val_loss: 0.3596 - val_accuracy: 0.8537
# Epoch 55/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3204 - accuracy: 0.8658 - val_loss: 0.3589 - val_accuracy: 0.8581
# Epoch 56/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8672 - val_loss: 0.3584 - val_accuracy: 0.8594
# Epoch 57/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3201 - accuracy: 0.8677 - val_loss: 0.3592 - val_accuracy: 0.8594
# Epoch 58/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3200 - accuracy: 0.8659 - val_loss: 0.3589 - val_accuracy: 0.8581
# Epoch 59/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3198 - accuracy: 0.8678 - val_loss: 0.3594 - val_accuracy: 0.8587
# Epoch 60/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3196 - accuracy: 0.8667 - val_loss: 0.3599 - val_accuracy: 0.8556
# Epoch 61/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3198 - accuracy: 0.8673 - val_loss: 0.3591 - val_accuracy: 0.8600
# Epoch 62/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3187 - accuracy: 0.8672 - val_loss: 0.3597 - val_accuracy: 0.8544
# Epoch 63/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3192 - accuracy: 0.8670 - val_loss: 0.3608 - val_accuracy: 0.8562
# Epoch 64/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3192 - accuracy: 0.8680 - val_loss: 0.3598 - val_accuracy: 0.8575
# Epoch 65/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3187 - accuracy: 0.8677 - val_loss: 0.3596 - val_accuracy: 0.8562
# Epoch 66/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3189 - accuracy: 0.8677 - val_loss: 0.3606 - val_accuracy: 0.8562
# Epoch 67/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.8670 - val_loss: 0.3601 - val_accuracy: 0.8575
# Epoch 68/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3184 - accuracy: 0.8684 - val_loss: 0.3599 - val_accuracy: 0.8581
# Epoch 69/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3182 - accuracy: 0.8672 - val_loss: 0.3599 - val_accuracy: 0.8575
# Epoch 70/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3177 - accuracy: 0.8661 - val_loss: 0.3605 - val_accuracy: 0.8556
# Epoch 71/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3177 - accuracy: 0.8678 - val_loss: 0.3595 - val_accuracy: 0.8556
# Epoch 72/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3179 - accuracy: 0.8684 - val_loss: 0.3605 - val_accuracy: 0.8550
# Epoch 73/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3179 - accuracy: 0.8680 - val_loss: 0.3606 - val_accuracy: 0.8562
# Epoch 74/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3175 - accuracy: 0.8667 - val_loss: 0.3601 - val_accuracy: 0.8556
# Epoch 75/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.8698 - val_loss: 0.3607 - val_accuracy: 0.8525
# Epoch 76/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3175 - accuracy: 0.8647 - val_loss: 0.3602 - val_accuracy: 0.8581
# Epoch 77/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3170 - accuracy: 0.8677 - val_loss: 0.3625 - val_accuracy: 0.8550
# Epoch 78/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3171 - accuracy: 0.8678 - val_loss: 0.3606 - val_accuracy: 0.8569
# Epoch 79/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3173 - accuracy: 0.8689 - val_loss: 0.3606 - val_accuracy: 0.8550
# Epoch 80/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3170 - accuracy: 0.8672 - val_loss: 0.3612 - val_accuracy: 0.8606
# Epoch 81/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3172 - accuracy: 0.8675 - val_loss: 0.3611 - val_accuracy: 0.8581
# Epoch 82/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3171 - accuracy: 0.8672 - val_loss: 0.3642 - val_accuracy: 0.8531
# Epoch 83/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3166 - accuracy: 0.8683 - val_loss: 0.3608 - val_accuracy: 0.8562
# Epoch 84/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3170 - accuracy: 0.8664 - val_loss: 0.3608 - val_accuracy: 0.8569
# Epoch 85/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3165 - accuracy: 0.8661 - val_loss: 0.3621 - val_accuracy: 0.8581
# Epoch 86/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3166 - accuracy: 0.8680 - val_loss: 0.3613 - val_accuracy: 0.8594
# Epoch 87/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3163 - accuracy: 0.8686 - val_loss: 0.3615 - val_accuracy: 0.8575
# Epoch 88/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3165 - accuracy: 0.8666 - val_loss: 0.3616 - val_accuracy: 0.8562
# Epoch 89/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3164 - accuracy: 0.8658 - val_loss: 0.3614 - val_accuracy: 0.8562
# Epoch 90/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3169 - accuracy: 0.8677 - val_loss: 0.3610 - val_accuracy: 0.8587
# Epoch 91/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3163 - accuracy: 0.8684 - val_loss: 0.3618 - val_accuracy: 0.8562
# Epoch 92/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3166 - accuracy: 0.8683 - val_loss: 0.3617 - val_accuracy: 0.8575
# Epoch 93/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3156 - accuracy: 0.8680 - val_loss: 0.3629 - val_accuracy: 0.8556
# Epoch 94/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3161 - accuracy: 0.8684 - val_loss: 0.3617 - val_accuracy: 0.8575
# Epoch 95/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3161 - accuracy: 0.8681 - val_loss: 0.3631 - val_accuracy: 0.8581
# Epoch 96/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3157 - accuracy: 0.8697 - val_loss: 0.3635 - val_accuracy: 0.8525
# Epoch 97/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3159 - accuracy: 0.8684 - val_loss: 0.3626 - val_accuracy: 0.8556
# Epoch 98/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3154 - accuracy: 0.8680 - val_loss: 0.3646 - val_accuracy: 0.8537
# Epoch 99/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3161 - accuracy: 0.8691 - val_loss: 0.3631 - val_accuracy: 0.8550
# Epoch 100/100
# 200/200 [==============================] - 0s 2ms/step - loss: 0.3156 - accuracy: 0.8670 - val_loss: 0.3629 - val_accuracy: 0.8569

# %%
y_log = model.predict(X_test_trf)

# %%
y_log
# Out:
# array([[0.24387243],
#        [0.33641678],
#        [0.1407485 ],
#        ...,
#        [0.2603802 ],
#        [0.1478239 ],
#        [0.24757475]], dtype=float32)

# %%
y_pred = np.where(y_log > 0.5, 1, 0)

# %%
y_pred
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8555

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
